# %% [markdown]
# 进入编辑模式： esc + m
# 进入代码模式： esc + y
# 快捷键显示： esc + h

# %% [markdown]
# # 零碎的知识点
#
#
# ### 多行语句
#   Python 通常是一行写完一条语句，但如果语句很长，我们可以使用反斜杠(\)来实现多行语句，例如：
#     ```
#     total = item_one + \
#         item_two + \
#         item_three
#         ```
#
#   在 [], {}, 或 () 中的多行语句，不需要使用反斜杠(\)，例如：
#     ```
#     total = ['item_one', 'item_two', 'item_three',
#         'item_four', 'item_five']
#     ```
# ### 同一行显示多条语句
#       Python可以在同一行中使用多条语句，语句之间使用分号(;)分割，如：
# `import sys; x = 'runoob'; sys.stdout.write(x + '\n')`
#
# ### 判断变量类型
#   可用 type() 函数或者 isinstance（） 来判断。
#   a=111
#   isinstance(a, int)
#
# isinstance 和 type 的区别在于：type()不会认为子类是一种父类类型。isinstance()会认为子类是一种父类类型。

# %% [markdown]
# # 输入
#     name=input("请输入名字") 输入字符串并赋值给name。不过未必需要赋值。
#
#
# ### 多个变量赋值
#   `a = b = c = 1`
#
#   `a, b, c = 1, 2, "runoob"`

# %% [markdown]
# # import 与 from...import
# 在 python 用 import 或者 from...import 来导入相应的模块。
#
# 将整个模块(somemodule)导入，格式为： `import somemodule`
#
# 从某个模块中导入某个函数,格式为： `from somemodule import somefunction`
#
# 从某个模块中导入多个函数,格式为： `from somemodule import firstfunc, secondfunc, thirdfunc`
#
# 将某个模块中的全部函数导入，格式为： `from somemodule import *`

# %%
导入 sys 模块
import sys
print('================Python import mode==========================')
print ('命令行参数为:')
for i in sys.argv:
    print (i)
print ('\n python 路径为',sys.path)

#导入 sys 模块的 argv,path 成员
from sys import argv,path  #  导入特定的成员
 
print('================python from import===================================')
print('path:',path) # 因为已经导入path成员，所以此处引用时不需要加sys.path

# %% [markdown]
# # 输出
#   print 默认输出是换行的，如果要实现不换行需要在变量末尾加上 end=""：
#     如 `print( y, end=" " )`
#     想

# %%
print("hello","world","!",sep="、",end="||")#分隔符sep， 结束字符end
# Out:
# hello、world、!||

# %% [markdown]
# # 六大标准数据类型
#   Python3 中有六个标准的数据类型：
#
#     Number（数字）
#     String（字符串）
#     List（列表）
#     Tuple（元组）
#     Set（集合）
#     Dictionary（字典）
#     Python3 的六个标准数据类型中：
#
#    不可变数据（3 个）：Number（数字）、String（字符串）、Tuple（元组）；
#     可变数据（3 个）：List（列表）、Dictionary（字典）、Set（集合）

# %% [markdown]
# # 数字
# ### 数字类型
#   python中数字有四种类型：整数、布尔型、浮点数和复数。其中复数为complex（）
#
# ### 算术运算
#
# ![%E5%9B%BE%E7%89%871.png](attachment:%E5%9B%BE%E7%89%871.png)
#
# ### Python运算符优先级
#
# |运算符|	描述|
# |:- | - |
# |**	|指数 (最高优先级)|
# |~ + -	|按位翻转, 一元加号和减号 (最后两个的方法名为 +@ 和 -@)|
# |* / % //	|乘，除，求余数和取整除|
# |+ -	|加法减法|
# |>> <<	|右移，左移运算符|
# |&	|位 'AND'|
# |^ 	|位运算符|
# |<= < > >=	|比较运算符|
# |== !=	|等于运算符|
# |= %= /= //= -= += *= **=	|赋值运算符|
# |is is not	|身份运算符|
# |in not in	|成员运算符|
# |not and or	|逻辑运算符|
#
# ps:位运算符还有个 | ，这里显示不出来

# %% [markdown]
# # 字符串
# ### 字符串下标![%E5%9B%BE%E7%89%872.png](attachment:%E5%9B%BE%E7%89%872.png)
#
# ### 字符串查询判断
#   判断语句
#     `if "hello" in my_string`
#     `if "hello" not in my_string`
#     ，其中my_string 是一个字符串
#
# ### 字符串替换
#    `my_string.replace("0","-")`
#
# ### 原句输出
#    `print(r'Ru\noob')` 输出“Ru\noob”，添加r，r即 raw 的简称，未加工的、原始的
#
# ### Python转义字符
#   在需要在字符中使用特殊字符时，python 用反斜杠 \ 转义字符。
#   常见的有：
#
#   | 转义字符 | 描述 |
# | :-----| ----: |
#     |\\(在行尾时)|续行符	|
#     |\\\\	|反斜杠符号|
#     |\\\"	|双引号|
#     |\a	|响铃	|
#     |\b	|退格(Backspace)	|
#     |\000|	空	|
#     |\n	|换行	|
#     |\v	|纵向制表符|
#     |\t	|横向制表符	|
#     |\r	|回车，将 \r 后面的内容移到字符串开头，并逐一替换开头部分的字符，直至将 \r 后面的内容完全替换完成。	|
#     |\f	|换页	|
#
#   [详见地址](https://www.runoob.com/python3/python3-string.html)
#
# ### Python字符串内建函数
#   [详见地址](https://www.runoob.com/python3/python3-string.html)
#   在最后一栏

# %% [markdown]
# # 列表
# ### 列表的删除操作
#     删除操作的方法或函数有：del 语句、pop（）方法、remove() 方法。
#     del list1[0]删除第0项的值。
#
#     tem=list1.pop() 删除末尾的值，并传给临时变量tem。
#     list1.pop(0) 删除第0项的值，并传给临时变量tem。
#
#     list1.remove('31') 删除第一个值为‘31’的值。
#
# ### 列表的修改操作
#     list1[1]='28' 直接按下标修改
#
# ### 列表的添加操作
#     list1.append('39')  在列表末尾删除
#
# ### 列表的插入操作
#     list1.insert(0,'39')  指定下标插入指定值
#
# ### 列表的访问操作
#     list1[0]  直接指定下标
#
# ### 列表的截取操作
#
#    ![列表截取 图例](https://www.runoob.com/wp-content/uploads/2014/08/list_slicing1_new1.png "列表截取")
#
# ### Python列表函数&方法
#    [详见地址](https://www.runoob.com/python3/python3-list.html)

# %%
list1=["30",'31']*5  
del str
print("原始列表为\n"+str(list1)+"\n")
del list1[0]
print(list1)
list1[1]='28'
print(list1)
# Out:
# 原始列表为
# ['30', '31', '30', '31', '30', '31', '30', '31', '30', '31']
#
# ['31', '30', '31', '30', '31', '30', '31', '30', '31']
# ['31', '28', '31', '30', '31', '30', '31', '30', '31']

# %% [markdown]
# # 元组 tuple
#   `tuple = ( 'abcd', 786 , 2.23, 'runoob', 70.2  )`
#
#   构造包含 0 个或 1 个元素的元组比较特殊，所以有一些额外的语法规则：
#    `tup1 = ()    # 空元组`
#
#    `tup2 = (20,) # 一个元素，需要在元素后添加逗号`
#
#   `tup[0] = 11  # 修改元组元素的操作是非法的`
#
#   元组的操作基本跟字符串相同。
#   元组与列表类似，不同之处在于元组的元素不能修改

# %% [markdown]
# # Set（集合）
#   集合（set）是由一个或数个形态各异的大小整体组成的，构成集合的事物或对象称作元素或是成员。
#
# 基本功能是进行成员关系测试和删除重复元素。
#
# 可以使用大括号 { } 或者 set() 函数创建集合，注意：创建一个空集合必须用 set() 而不是 { }，因为 { } 是用来创建一个空字典。

# %%
#!/usr/bin/python3

sites = {'Google', 'Taobao', 'Runoob', 'Facebook', 'Zhihu', 'Baidu'}

print(sites)   # 输出集合，重复的元素被自动去掉

# 成员测试
if 'Runoob' in sites :
    print('Runoob 在集合中')
else :
    print('Runoob 不在集合中')


# set可以进行集合运算
a = set('abracadabra')
b = set('alacazam')

print(a)

print(a - b)     # a 和 b 的差集

print(a | b)     # a 和 b 的并集

print(a & b)     # a 和 b 的交集

print(a ^ b)     # a 和 b 中不同时存在的元素

# %% [markdown]
# # Dictionary（字典）
#   字典是一种映射类型，字典用 { } 标识，它是一个无序的 键(key) : 值(value) 的集合。
#
# 键(key)必须使用不可变类型。
#
# 在同一个字典中，键(key)必须是唯一的。
